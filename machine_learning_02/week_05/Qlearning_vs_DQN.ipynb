# %% [markdown]
# # 🧠 Reinforcement Learning Assignment: Q-Learning vs Deep Q-Network (DQN)
#
# In this assignment, you will experiment with two reinforcement learning methods—**Q-learning** and **Deep Q-Networks (DQN)**—on the `CartPole-v1` environment.
#
# ### 🎯 Objectives:
# - Understand the differences between tabular Q-learning and neural network-based DQN.
# - Adjust hyperparameters for both models and observe how they impact performance.
# - Compare the number of steps each model survives per episode.
#
# ### 📌 Instructions:
# 1. Run the provided Q-learning code and tune parameters.
# 2. Run the DQN code using `Stable-Baselines3` and tune parameters.
# 3. Record average episode rewards and compare both models.

# %% [markdown]
# ## 🔢 Q-learning Implementation (Discrete State Approximation)

# %%
# %pip install gymnasium stable-baselines3
# Out:
# Requirement already satisfied: gymnasium in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (1.1.1)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from stable-baselines3) (2.7.0)
# Requirement already satisfied: pandas in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from stable-baselines3) (3.10.3)
# Requirement already satisfied: filelock in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rewheaton/Code/rewheaton.github.io/.venv/lib/python3.11/site-packages (from pandas->stable-baselines3) (2025.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import numpy as np

env = gym.make('CartPole-v1')

def discretize(obs, bins):
    return tuple(np.digitize(x, bins[i]) for i, x in enumerate(obs))

n_bins = 6
bins = [np.linspace(-4.8, 4.8, n_bins), np.linspace(-5, 5, n_bins),
        np.linspace(-0.418, 0.418, n_bins), np.linspace(-5, 5, n_bins)]
q_table = np.zeros([n_bins] * 4 + [env.action_space.n])

alpha = 0.1
gamma = 0.99
epsilon = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01

episodes = 500
steps_per_episode = []

for ep in range(episodes):
    state, _ = env.reset()
    state = discretize(state, bins)
    done = False
    total_steps = 0

    while not done:
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state])

        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_discrete = discretize(next_state, bins)
        best_next = np.max(q_table[next_discrete])
        q_table[state][action] += alpha * (reward + gamma * best_next - q_table[state][action])

        state = next_discrete
        total_steps += 1

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    steps_per_episode.append(total_steps)

print(f"Q-learning average steps: {np.mean(steps_per_episode):.2f}")
# Out:
# Q-learning average steps: 15.43

# %% [markdown]
# ## 🧠 Deep Q-Network using Stable-Baselines3

# %% [markdown]
# The `DQN` class from **Stable-Baselines3** has several parameters you can adjust to control the training behavior of the Deep Q-Network. Here's a breakdown of the most important ones:
#
# ---
#
# ## 🧠 **Key Parameters of `DQN` in Stable-Baselines3**
#
# ### 🎯 Core Parameters
#
# | Parameter                 | Description                                                    | Typical Values               |
# | ------------------------- | -------------------------------------------------------------- | ---------------------------- |
# | `policy`                  | Neural network architecture. `"MlpPolicy"` for MLPs (default). | `"MlpPolicy"`, `"CnnPolicy"` |
# | `env`                     | The Gym environment to train on.                               | `gym.make("CartPole-v1")`    |
# | `learning_rate`           | Step size for the optimizer.                                   | `1e-4` to `1e-3`             |
# | `buffer_size`             | Replay buffer size (how many experiences to store).            | `10_000` to `100_000`        |
# | `learning_starts`         | Timesteps before training starts (buffer warm-up).             | `1_000`                      |
# | `batch_size`              | Size of mini-batches sampled from the buffer.                  | `32`, `64`, `128`            |
# | `tau`                     | Soft update coefficient for the target network.                | `1.0` (hard update)          |
# | `gamma`                   | Discount factor for future rewards.                            | `0.95` to `0.99`             |
# | `train_freq`              | Frequency of training the model.                               | `4` (every 4 steps)          |
# | `target_update_interval`  | Steps between target network updates.                          | `100` to `1000`              |
# | `exploration_fraction`    | Fraction of total timesteps to decay epsilon.                  | `0.1`                        |
# | `exploration_initial_eps` | Initial epsilon for exploration.                               | `1.0`                        |
# | `exploration_final_eps`   | Final epsilon after decay.                                     | `0.05` to `0.01`             |
# | `max_grad_norm`           | Gradient clipping value.                                       | `10`                         |
# | `verbose`                 | Verbosity level (0: silent, 1: info, 2: debug).                | `1`                          |
#
# ---
#
# ### 🧪 Example Usage
#
# ```python
# from stable_baselines3 import DQN
#
# model = DQN(
#     "MlpPolicy",
#     env,
#     learning_rate=1e-4,
#     buffer_size=50000,
#     learning_starts=1000,
#     batch_size=64,
#     tau=1.0,
#     gamma=0.99,
#     train_freq=4,
#     target_update_interval=500,
#     exploration_fraction=0.1,
#     exploration_initial_eps=1.0,
#     exploration_final_eps=0.01,
#     verbose=1
# )
# ```
#
# ---
#
# ### 📚 Optional Parameters
#
# | Parameter         | Purpose                                             |
# | ----------------- | --------------------------------------------------- |
# | `tensorboard_log` | Path to log directory for TensorBoard visualization |
# | `device`          | `"cpu"` or `"cuda"` to specify hardware             |
# | `seed`            | Random seed for reproducibility                     |

# %%
import gymnasium as gym
from stable_baselines3 import DQN

env = gym.make('CartPole-v1')

model = DQN('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=50000)
model.save('dqn_cartpole')
print("✅ DQN training complete!")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 42602    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3521     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 171      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.547    |
# |    n_updates        | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4021     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 239      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4245     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 299      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.501    |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4446     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 356      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.443    |
# |    n_updates        | 63       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4675     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 462      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.418    |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4907     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 582      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.308    |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5004     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 659      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.275    |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5090     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 805      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.199    |
# |    n_updates        | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5165     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 870      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5281     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 993      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5325     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1057     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5380     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1146     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 261      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5426     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1224     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0925   |
# |    n_updates        | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5446     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1292     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0552   |
# |    n_updates        | 297      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5477     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1363     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0635   |
# |    n_updates        | 315      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5497     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1440     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0508   |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5520     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 355      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5543     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1626     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 381      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5554     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1694     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 398      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5547     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1749     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5547     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1813     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5565     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1928     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5557     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1996     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 473      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5564     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2120     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 504      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5563     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2189     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5562     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2274     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 543      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5574     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2338     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5574     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00863  |
# |    n_updates        | 575      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5558     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2450     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00735  |
# |    n_updates        | 587      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5564     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2508     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00579  |
# |    n_updates        | 601      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5558     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2560     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00581  |
# |    n_updates        | 614      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 5553     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2635     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00621  |
# |    n_updates        | 633      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5559     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2704     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00478  |
# |    n_updates        | 650      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 5559     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2766     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00554  |
# |    n_updates        | 666      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5545     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2820     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00962  |
# |    n_updates        | 679      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18
|
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4930     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000459 |
# |    n_updates        | 1207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.0557   |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5181     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4970     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000501 |
# |    n_updates        | 1217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5179     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5010     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000538 |
# |    n_updates        | 1227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5176     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5048     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00078  |
# |    n_updates        | 1236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5172     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5087     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000714 |
# |    n_updates        | 1246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5162     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5129     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000465 |
# |    n_updates        | 1257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5159     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5170     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000967 |
# |    n_updates        | 1267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5151     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5208     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5146     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5250     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000637 |
# |    n_updates        | 1287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# ...
# |    total_timesteps  | 47183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 11770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 4654     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47282    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 11795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 4654     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 11820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 4654     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47489    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 11847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0858   |
# |    n_updates        | 11866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 11888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00937  |
# |    n_updates        | 11906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47806    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0729   |
# |    n_updates        | 11926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47890    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 11947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 4656     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 47980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 11969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 4656     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48058    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 11989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 4656     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48150    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 12012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 4656     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48239    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0492   |
# |    n_updates        | 12034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48319    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 12054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00875  |
# |    n_updates        | 12076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 12101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0686   |
# |    n_updates        | 12120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48662    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 12140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48750    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 12162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 4655     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48841    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 12185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 4656     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48958    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 12214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49076    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.048    |
# |    n_updates        | 12243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 12270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 4657     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49279    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 12294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0745   |
# |    n_updates        | 12318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49454    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 12338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49527    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 12356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 4658     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49643    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 12385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 4659     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49745    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 12411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 4659     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 12435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 4660     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 49949    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00821  |
# |    n_updates        | 12462    |
# ----------------------------------
# ✅ DQN training complete!

# %% [markdown]
# The **training log** from a `Stable-Baselines3` DQN model. This output helps you monitor training progress and evaluate how well your agent is learning over time.
#
# Here's how to interpret each section:
#
# ---
#
# ## 📦 **Section: `rollout/`**
#
# This shows **behavior of the agent during evaluation episodes** (not used for training directly).
#
# | Metric             | Meaning                                                                                                                                                                           |
# | ------------------ | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `ep_len_mean`      | 🕒 Average number of steps the agent survives per episode (i.e., how long it balances the pole). `24.5` means your agent typically survives \~24 steps.                           |
# | `ep_rew_mean`      | 💰 Average reward per episode. In `CartPole-v1`, the reward is `+1` per timestep survived, so this equals `ep_len_mean`.                                                          |
# | `exploration_rate` | 🎲 Current value of epsilon (𝜖), controlling randomness in action selection. `0.05` means the agent explores 5% of the time and exploits (uses the best action) 95% of the time. |
#
# ---
#
# ## ⏱️ **Section: `time/`**
#
# This shows training duration and speed.
#
# | Metric            | Meaning                                                                                                            |
# | ----------------- | ------------------------------------------------------------------------------------------------------------------ |
# | `episodes`        | 🎬 Total number of episodes completed so far.                                                                      |
# | `fps`             | ⏩ Training speed in **frames per second**. `1094` means it's simulating 1,094 timesteps per second.                |
# | `time_elapsed`    | ⏱️ Total wall-clock time elapsed (in seconds).                                                                     |
# | `total_timesteps` | 🔁 Total number of environment steps taken. `49958` is very close to your `total_timesteps=50000` training target. |
#
# ---
#
# ## 🧠 **Section: `train/`**
#
# This shows training-specific stats during updates to the model.
#
# | Metric          | Meaning                                                                                                                                                            |
# | --------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | `learning_rate` | 🔧 Current learning rate (step size).                                                                                                                              |
# | `loss`          | 📉 Temporal Difference (TD) loss. This is how wrong the Q-network's predictions are. Lower is generally better, and `0.0115` is quite low, indicating convergence. |
# | `n_updates`     | 🔁 Number of times the model has updated its weights using batches from the replay buffer.                                                                         |
#
# ---
#
# ## 🧪 Summary
#
# * Your agent has **stopped exploring much** (`epsilon = 0.05`).
# * It's **learning slowly but steadily**, with a **low loss**.
# * But **average reward is still low (`24.5`)**, meaning it hasn't learned to balance the pole well yet.
#
#   * Possible reasons:
#
#     * Not enough training (`50k` steps may be too few)
#     * Need to tune hyperparameters (like `learning_rate`, `buffer_size`, etc.)
#     * DQN may need better network architecture or longer training

# %% [markdown]
# ## 📊 Evaluation
# After running both training methods, evaluate their performance by calculating average steps per episode.
#
# You can re-run the environment using the trained models and compare results.
#
# ### ✍️ Compare:
# - How does discretization impact Q-learning performance?
# - How much better does DQN perform?
# - What parameter changes made the biggest difference?

# %% [markdown]
# - How does discretization impact Q-learning performance?
#     - Discretization groups similar states together so information required for optimial decisions may be lost.
# - How much better does DQN perform?
#     - DQN performs 193.8% better mostly due to how corse the Q-Learning bins are. Increasing the number of bins can close that gap.
# - What parameter changes made the biggest difference?
#     - For Q-Learning, the numbers of bins has the biggest impact at the cost of longer training time. For DQN, the number of timesteps seems to have a large impact. Both parameters indicate that more training typically results in better performance.

# %%
# Evaluate Q-Learning
def evaluate_qlearning(q_table, bins, episodes=100):
    env = gym.make('CartPole-v1')
    total_steps = []
    
    for _ in range(episodes):
        state, _ = env.reset()
        state = discretize(state, bins)
        steps = 0
        done = False
        
        while not done:
            action = np.argmax(q_table[state])  # No exploration during evaluation
            next_state, _, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            state = discretize(next_state, bins)
            steps += 1
            
        total_steps.append(steps)
    
    return np.mean(total_steps)

# Evaluate DQN
def evaluate_dqn(model, episodes=100):
    env = gym.make('CartPole-v1')
    total_steps = []
    
    for _ in range(episodes):
        obs, _ = env.reset()
        steps = 0
        done = False
        
        while not done:
            action, _ = model.predict(obs, deterministic=True)  # No exploration
            obs, _, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            steps += 1
            
        total_steps.append(steps)
    
    return np.mean(total_steps)

q_learning_avg = evaluate_qlearning(q_table, bins)
dqn_avg = evaluate_dqn(model)

print(f"Q-Learning average steps: {q_learning_avg:.2f}")
print(f"DQN average steps: {dqn_avg:.2f}")
print(f"DQN improvement: {(dqn_avg/q_learning_avg)*100:.1f}% better")
# Out:
# Q-Learning average steps: 12.80
# DQN average steps: 24.80
# DQN improvement: 193.8% better
